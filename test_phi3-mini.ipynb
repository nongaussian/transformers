# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
model = AutoModelForCausalLM.from_pretrained(
    "microsoft/Phi-3-mini-4k-instruct",
    device_map="cuda",
    torch_dtype="auto",
    trust_remote_code=True,
)
# Out:
# `flash-attention` package not found, consider installing for better performance: No module named 'flash_attn'.
# Current `flash-attention` does not support `window_size`. Either upgrade or use `attn_implementation='eager'`.
# Loading checkpoint shards: 100%|██████████| 2/2 [00:12<00:00,  6.43s/it]

# %%
tokenizer = AutoTokenizer.from_pretrained("microsoft/Phi-3-mini-4k-instruct")

# %%
inputs = tokenizer("Tell me the birth story of the Universe.", return_tensors="pt").to("cuda")

# %%
with torch.no_grad():
    outputs = model.generate(
    **inputs,
    max_new_tokens=300,
    temperature=0.7,
    top_p=0.9,
    do_sample=True
    )
response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
# You are not running the flash-attention implementation, expect numerical differences.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 with torch.no_grad():
# ----> 2     outputs = model.generate(
#       3     **inputs,
#       4     max_new_tokens=300,
#       5     temperature=0.7,
#       6     top_p=0.9,
#       7     do_sample=True
#       8     )
#       9 response = tokenizer.decode(outputs[0], skip_special_tokens=True)
#      10 print(response)
#
# File /opt/conda/lib/python3.11/site-packages/torch/utils/_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File /workspace/transformers/src/transformers/generation/utils.py:2635, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, use_model_defaults, custom_generate, **kwargs)
#    2627     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2628         input_ids=input_ids,
#    2629         expand_size=generation_config.num_return_sequences,
#    2630         is_encoder_decoder=self.config.is_encoder_decoder,
#    2631         **model_kwargs,
#    2632     )
#    2634     # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2635     result = self._sample(
#    2636         input_ids,
#    2637         logits_processor=prepared_logits_processor,
#    2638         stopping_criteria=prepared_stopping_criteria,
#    2639         generation_config=generation_config,
#    2640         synced_gpus=synced_gpus,
#    2641         streamer=streamer,
#    2642         **model_kwargs,
#    2643     )
#    2645 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    2646     # 11. interleave input_ids with `num_beams` additional sequences per batch
#    2647     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2648         input_ids=input_ids,
#    2649         expand_size=generation_config.num_beams,
#    2650         is_encoder_decoder=self.config.is_encoder_decoder,
#    2651         **model_kwargs,
#    2652     )
#
# File /workspace/transformers/src/transformers/generation/utils.py:3619, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    3617     is_prefill = False
#    3618 else:
# -> 3619     outputs = model_forward(**model_inputs, return_dict=True)
#    3621 # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#    3622 model_kwargs = self._update_model_kwargs_for_generation(
#    3623     outputs,
#    3624     model_kwargs,
#    3625     is_encoder_decoder=self.config.is_encoder_decoder,
#    3626 )
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/.cache/huggingface/modules/transformers_modules/microsoft/Phi-3-mini-4k-instruct/0a67737cc96d2554230f90338b163bc6380a2a85/modeling_phi3.py:1243, in Phi3ForCausalLM.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1240 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1242 # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# -> 1243 outputs = self.model(
#    1244     input_ids=input_ids,
#    1245     attention_mask=attention_mask,
#    1246     position_ids=position_ids,
#    1247     past_key_values=past_key_values,
#    1248     inputs_embeds=inputs_embeds,
#    1249     use_cache=use_cache,
#    1250     output_attentions=output_attentions,
#    1251     output_hidden_states=output_hidden_states,
#    1252     return_dict=return_dict,
#    1253 )
#    1255 hidden_states = outputs[0]
#    1256 logits = self.lm_head(hidden_states)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/.cache/huggingface/modules/transformers_modules/microsoft/Phi-3-mini-4k-instruct/0a67737cc96d2554230f90338b163bc6380a2a85/modeling_phi3.py:1121, in Phi3Model.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1111     layer_outputs = self._gradient_checkpointing_func(
#    1112         decoder_layer.__call__,
#    1113         hidden_states,
#    (...)   1118         use_cache,
#    1119     )
#    1120 else:
# -> 1121     layer_outputs = decoder_layer(
#    1122         hidden_states,
#    1123         attention_mask=attention_mask,
#    1124         position_ids=position_ids,
#    1125         past_key_value=past_key_values,
#    1126         output_attentions=output_attentions,
#    1127         use_cache=use_cache,
#    1128     )
#    1130 hidden_states = layer_outputs[0]
#    1132 if use_cache:
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/.cache/huggingface/modules/transformers_modules/microsoft/Phi-3-mini-4k-instruct/0a67737cc96d2554230f90338b163bc6380a2a85/modeling_phi3.py:854, in Phi3DecoderLayer.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, **kwargs)
#     851 hidden_states = residual + self.resid_attn_dropout(attn_outputs)
#     853 residual = hidden_states
# --> 854 hidden_states = self.post_attention_layernorm(hidden_states)
#     855 hidden_states = self.mlp(hidden_states)
#     856 hidden_states = residual + self.resid_mlp_dropout(hidden_states)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# KeyboardInterrupt:
